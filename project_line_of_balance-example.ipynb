# %%
from line_of_balance import *
p = default_lob()

# %%
print(p.start_end())
print(p.start_first_to_start_last())
print(p.activity_duration_per_unit())
print(p.theoretical_gang_size())
print(p.actual_gang_size())
print(p.actual_output_rate())
print(p.man_hours_per_unit)
print(p.start_on_first_section())
print(p.end_on_first_section())
print(p.start_on_last_section())
print(p.end_on_last_section())
# Out:
# ([1, 8.12, 20.41, 33.07, 52.49], [3.12, 15.41, 24.16, 38.07, 54.83], [29.69, 42.79, 55.99, 64.74, 74.74], [32.81, 50.08, 59.74, 69.74, 77.08])
# [29.69, 34.67, 35.58, 31.67, 22.25]
# [3.12, 7.29, 3.75, 5.0, 2.34]
# [7.5, 26.25, 4.5, 15.0, 11.25]
# [8, 24, 4, 15, 16]
# [3.2, 2.74, 2.67, 3.0, 4.27]
# [100, 350, 60, 200, 150]
# [1, 8.12, 20.41, 33.07, 52.49]
# [3.12, 15.41, 24.16, 38.07, 54.83]
# [29.69, 42.79, 55.99, 64.74, 74.74]
# [32.81, 50.08, 59.74, 69.74, 77.08]

# %%
default_diagram()

# %%
from line_of_balance_table import *
create_excel_table()
